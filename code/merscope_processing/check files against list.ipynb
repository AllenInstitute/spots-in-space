# %%
import pandas as pd
from pathlib import Path

include = ['1172983297','1172983302','1172983307', '1175046718','1175046724','1175046730','1182389655','1182389662',
           '1182389669','1170797659','1174511265','1174511271','1176833728','1176833739','1176833749','1116997297',
           '1185930845','1185930850','1193169898','1192523789','1192523794','1194111462','1194111807','1194111812',
           '1195927756','1196150174','1194113131','1195928136','1195928141','1195928151','1218552402','1218552298',
           '1217499815','1217499820','1217499825','1217501462','1217501029','1217501037','1217501042','1217500876',
           '1218552392']
root = Path('/home/imaging_mfish/surveyNAS05/scratch/human/AD_MTG/resegmented_data_copies')
allfiles = root.glob('*')
filelist = [x.stem for x in allfiles if x.stem not in include]
print(filelist)
# Out:
# ['results', '1170797669', '1218552275', 'not_for_h5ad', '1170797664']
