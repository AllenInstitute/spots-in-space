# %%
import pandas as pd
from matplotlib import pyplot as plt
from pathlib import Path

to_plot = ['1196150174', '1194113131', '1195928141', '1170797664'] #1170797664 is not damaged
#to_plot = ['1170797664']
root_folder = '/home/imaging_mfish/surveyNAS05/scratch/human/AD_MTG/resegmented_data_copies/not_for_h5ad'
for p in to_plot:
    md_path = Path(root_folder).joinpath(p+'/region_0/cellpose_cyto2_nuclei_mask4/cellpose_metadata.csv')
    md = pd.read_csv(md_path)
    plt.figure()
    plt.scatter(md['center_y'], md['center_x'], marker = '.', s=2)
    plt.title(p)
