# %%
from sawg.hpc import run_slurm, run_slurm_func, run

# %%
job = run_slurm(
    hpc_host='hpc-login',
    job_path='/allen/programs/celltypes/workgroups/rnaseqanalysis/NHP_spatial/hpc-jobs',
    partition='celltypes', 
    job_name='test-job',
    nodes=1,
    ntasks=1,
    array='0-3',
    mincpus=1,
    mem='1G',
    time='0:05:00',
    command='srun echo $SLURM_ARRAY_TASK_ID',
    mail_user=None,
)    
    
while True:
    stat = job.state()
    print(stat)
    if job.is_done():
        break
# Out:
# {'8217539_0': <JobState RUNNING>, '8217539_1': <JobState COMPLETING>, '8217539_2': <JobState NO_INFO>, '8217539_3': <JobState NO_INFO>}

# %%
print(list(job)[1].output)
# Out:
# ==========================================
# SLURM_JOB_ID = 8217541
# Username = lukec
# Group = 10513
# SLURM_JOB_NODELIST = n250
# ==========================================
# 1

# %%
import time
run_spec = {i:(print, (f"test message {i}",), {}) for i in range(4)}

job = run_slurm_func(
    run_spec=run_spec,
    conda_env='/allen/programs/celltypes/workgroups/rnaseqanalysis/NHP_spatial/conda-envs/sawg',
    hpc_host='hpc-login',
    job_path='/allen/programs/celltypes/workgroups/rnaseqanalysis/NHP_spatial/hpc-jobs',
    partition='celltypes', 
    job_name='test-job',
    nodes=1,
    ntasks=1,
    array='0-3',
    mincpus=1,
    mem='1G',
    time='0:05:00',
    mail_user=None,
)    

while True:
    stat = job.state()
    print(stat)
    if job.is_done():
        break
    time.sleep(3)
# Out:
# {'8223767_0': <JobState RUNNING>, '8223767_1': <JobState RUNNING>, '8223767_2': <JobState RUNNING>, '8223767_3': <JobState RUNNING>}
# {'8223767_0': <JobState RUNNING>, '8223767_1': <JobState RUNNING>, '8223767_2': <JobState RUNNING>, '8223767_3': <JobState RUNNING>}
# {'8223767_0': <JobState RUNNING>, '8223767_1': <JobState RUNNING>, '8223767_2': <JobState RUNNING>, '8223767_3': <JobState RUNNING>}
# {'8223767_0': <JobState RUNNING>, '8223767_1': <JobState RUNNING>, '8223767_2': <JobState RUNNING>, '8223767_3': <JobState NO_INFO>}
# {'8223767_0': <JobState RUNNING>, '8223767_1': <JobState RUNNING>, '8223767_2': <JobState RUNNING>, '8223767_3': <JobState NO_INFO>}
# {'8223767_0': <JobState RUNNING>, '8223767_1': <JobState RUNNING>, '8223767_2': <JobState RUNNING>, '8223767_3': <JobState NO_INFO>}
# {'8223767_0': <JobState NO_INFO>, '8223767_1': <JobState NO_INFO>, '8223767_2': <JobState NO_INFO>, '8223767_3': <JobState NO_INFO>}

# %%
print(list(job)[3].error)

# %%
print(list(job)[3].output)
# Out:
# ==========================================
# SLURM_JOB_ID = 8223767
# Username = lukec
# Group = 10513
# SLURM_JOB_NODELIST = n239
# ==========================================
# Started HPC worker 3 from /allen/programs/celltypes/workgroups/rnaseqanalysis/NHP_spatial/conda-envs/sawg/bin/python
# Call spec file: /allen/programs/celltypes/workgroups/rnaseqanalysis/NHP_spatial/hpc-jobs/test-job_func.pkl
# Invoking callback: <built-in function print>
# -----------------------------
# test message 3
# -----------------------------
# HPC worker complete. Callback returned:
# None
